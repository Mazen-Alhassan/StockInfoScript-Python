# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

# %%
stock = ["AAPL", "XRP"]

yf.download(stock, start = "2010-01-01", end = "2020-11-11")
# Out:
# [*********************100%***********************]  2 of 2 completed
# Price                       Adj Close              Close               High  \
# Ticker                           AAPL    XRP        AAPL    XRP        AAPL
# Date
# 2010-01-04 00:00:00+00:00    6.454504  0.178    7.643214  0.178    7.660714
# 2010-01-05 00:00:00+00:00    6.465665  0.178    7.656429  0.178    7.699643
# 2010-01-06 00:00:00+00:00    6.362821  0.189    7.534643  0.189    7.686786
# 2010-01-07 00:00:00+00:00    6.351056  0.184    7.520714  0.184    7.571429
# 2010-01-08 00:00:00+00:00    6.393281    NaN    7.570714    NaN    7.571429
# ...                               ...    ...         ...    ...         ...
# 2020-11-04 00:00:00+00:00  112.334282    NaN  114.949997    NaN  115.589996
# 2020-11-05 00:00:00+00:00  116.321442    NaN  119.029999    NaN  119.620003
# 2020-11-06 00:00:00+00:00  116.189301    NaN  118.690002    NaN  119.199997
# ...
